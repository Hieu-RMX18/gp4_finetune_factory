# %% [markdown]
# # Kaggle Fallback: GP4 Qwen2.5-7B Unsloth QLoRA
#
# Use only after Colab quota is unavailable and the user approves switching platform. Store tokens in Kaggle Secrets.

# %%
from pathlib import Path
PROJECT_DIR = Path('/kaggle/input/gp4-finetune-factory')
TRAIN_SPLIT = PROJECT_DIR / 'data/splits/train.jsonl'
if not TRAIN_SPLIT.exists():
    raise FileNotFoundError('Upload validated splits before starting Kaggle training.')

# %%
# !python -m pip install -q unsloth datasets trl

# %% [markdown]
# Training cells should mirror the Colab pilot after GPU/quota status is confirmed. Do not use alternate accounts or quota bypasses.
