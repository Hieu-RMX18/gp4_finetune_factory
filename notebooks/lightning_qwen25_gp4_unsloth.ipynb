# %% [markdown]
# # Lightning AI Fallback: GP4 Qwen2.5-7B Unsloth QLoRA
#
# Use only after free/approved compute is available. Keep secrets in the platform secret manager.

# %%
from pathlib import Path
PROJECT_DIR = Path.cwd()
TRAIN_SPLIT = PROJECT_DIR / 'data/splits/train.jsonl'
if not TRAIN_SPLIT.exists():
    raise FileNotFoundError('Run validation and split building before training.')

# %%
# !python -m pip install -q unsloth datasets trl

# %% [markdown]
# Mirror the Colab training cell after confirming GPU availability. Stop and write `reports/platform_status.md` if quota, auth, or billing blocks appear.
